# %%
# %%capture
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd
import pickle

# %%
from echogram import EchoGram
# Out:
# 0it [00:00, ?it/s]

# %% [markdown]
# ### October 2021 datasets:
# - './log-data/Sonar_2021-10-16_12.53.38.sl2'
# - './log-data/Sonar_2021-10-16_13.29.30.sl2'
# - './log-data/Sonar_2021-10-16_13.29.36.sl2'
# - './log-data/Sonar_2021-10-16_14.21.09.sl2'
# - './log-data/Sonar_2021-10-16_14.38.24.sl2'

# %% [markdown]
# ## Visualize image segments with "hot" colors

# %%
fig = plt.figure()
ax1 = echo_4mph_101621.df.plot.scatter(x="longitude", y="latitude")
echo_4mph_101621.df.loc[9600:10800,:].plot.scatter(x="longitude", y="latitude", c='red', ax=ax1)

# %%
plt.imshow(echo_4mph_101621.echo[:,int(cols*9/10):-1],)
plt.colorbar()

# %%
plt.imshow(echo_4mph_101621.echo[:,int(cols/2):int(cols*2.8/5)], cmap='hot', vmin=vmin, vmax=vmax)
plt.colorbar()

# %%
plt.imshow(echo_4mph_101621.echo[:,9600:10800], cmap='hot', vmin=vmin, vmax=vmax)

# %% [markdown]
# ## File:Sonar_2021-10-16_13.29.36 Speed=6mph

# %%
echogram6mph_101621 = EchoGram('./log-data/Sonar_2021-10-16_13.29.36.sl2', channels=[5])
# Out:
#   0%|          | 0.00/327M [00:00<?, ?B/s]

# %%
# with open('processed_data/echogram6mph_101621.txt', 'rb') as file:
#     # Call load method to deserialze
#     echogram6mph_101621 = pickle.load(file)
    
with open('processed_data/echogram6mph_101621.txt', 'wb') as file:
    # A new file will be created
    pickle.dump(echogram6mph_101621, file)

# %%
print("length:",len(echogram6mph_101621.data))
fig = plt.figure()
ax2 = echogram6mph_101621.df.plot.scatter(x="longitude", y="latitude")
echogram6mph_101621.df.loc[5600:6400,:].plot.scatter(x="longitude", y="latitude", c='red', ax=ax2)

# %%
plt.imshow(echogram6mph_101621.echo[:,5600:6400], cmap='hot')

# %% [markdown]
# ## File:Sonar_2021-10-16_14.38.24 Speed=7mph

# %%
echogram7mph_101621 = EchoGram('./log-data/Sonar_2021-10-16_14.38.24.sl2', channels=[5])

# %%
print("length:",len(echogram7mph_101621.data))
fig = plt.figure()
ax3 = echogram7mph_101621.df.plot.scatter(x="longitude", y="latitude")
echogram7mph_101621.df.loc[4400:5000,:].plot.scatter(x="longitude", y="latitude", c='red', ax=ax3)

# %%
vmin=min(echogram7mph_101621.echo.flat)
vmax=max(echogram7mph_101621.echo.flat)
plt.imshow(echogram7mph_101621.echo[:,4400:5000], cmap='hot', vmin=vmin, vmax=vmax)

# %% [markdown]
# # DownScan Sonar

# %%
downscan = EchoGram('./log-data/Sonar_2021-10-16_12.53.38.sl2', channels=[2], depthline=False)

# %%
plt.imshow(downscan.echo[:,9600:10800], cmap='hot')

# %% [markdown]
# # Force sensor and objects testing

# %%
echo_1_051722 = EchoGram('./log-data/Sonar_2022-05-17_13.01.43.sl2', channels=[5])
# Out:
#   0%|          | 0.00/332M [00:00<?, ?B/s]

# %%
echo_2_051722 = EchoGram('./log-data/Sonar_2022-05-17_13.26.21.sl2', channels=[5])
# Out:
#   0%|          | 0.00/119M [00:00<?, ?B/s]

# %%
print(echo_1_051722.df.columns)
# Out:
# Index(['offset', 'previous_primary_offset', 'previous_secondary_offset',
#        'previous_downscan_offset', 'previous_left_sidescan_offset',
#        'previous_right_sidescan_offset', 'previous_composite_sidescan_offset',
#        'framesize', 'previous_framesize', 'channel', 'packetsize',
#        'frame_index', 'upper_limit', 'lower_limit', 'frequency', 'water_depth',
#        'keel_depth', 'gps_speed', 'temperature', 'lon_enc', 'lat_enc',
#        'water_speed', 'course', 'altitude', 'heading', 'flags', 'time1',
#        'has_altitude', 'has_heading', 'has_track', 'has_water_speed',
#        'has_position', 'has_packet', 'has_temperature', 'has_gps_speed',
#        'gps_speed_kph', 'longitude', 'latitude', 'water_depth_m', 'headersize',
#        'heading_deg', 'X_m', 'Y_m'],
#       dtype='object')

# %%
print("Checking the echo_1_051722 variable exists. Type: ", type(echo_1_051722))   
with open('processed_data/echo_1_051722.txt', 'wb') as fl:  
    pickle.dump(echo_1_051722, fl)
print("Checking the echo_2_051722 variable exists. Type: ", type(echo_2_051722))   
with open('processed_data/echo_2_051722.txt', 'wb') as fl:  
    pickle.dump(echo_2_051722, fl)
# Out:
# Checking the echo_1_051722 variable exists. Type:  <class 'echogram.EchoGram'>
# Checking the echo_2_051722 variable exists. Type:  <class 'echogram.EchoGram'>

# %%
with open('processed_data/echo_1_051722.txt', 'rb') as fl:
    echo_1_051722 = pickle.load(fl)
with open('processed_data/echo_2_051722.txt', 'rb') as fl:
    echo_2_051722 = pickle.load(fl)

# %%
import copy
echo_3_051722 = copy.deepcopy(echo_1_051722)
echo_6_051722 = copy.deepcopy(echo_1_051722)
echo_9_051722 = copy.deepcopy(echo_1_051722)
echo_12_051722 = copy.deepcopy(echo_2_051722)

# %%
def fix_time(df):
    return df['time1'] - df['time1'].to_numpy()[0]

for df in [echo_3_051722.df, echo_6_051722.df, echo_9_051722.df, echo_12_051722.df]:
    df['time1'] = fix_time(df)/1000

plt.plot(range(len(echo_12_051722.df)), echo_12_051722.df['time1'])

# %%
header = ["X_m", "Y_m", "time1"]
echo_3_051722.df.to_csv('force_traj_3.csv', columns = header)
echo_6_051722.df.to_csv('force_traj_6.csv', columns = header)
echo_9_051722.df.to_csv('force_traj_9.csv', columns = header)
echo_12_051722.df.to_csv('force_traj_12.csv', columns = header)

# %% [markdown]
# in the terminal: `mv ./force_traj_* ~/april_ws/src/bathydrone/gnc/traj_data`

# %% [markdown]
# ### Read the drone trajectory from csv

# %%
drone1 = pd.read_csv('./log-data/May-17th-2022-03-12PM-Flight-Airdata.csv')
drone2 = pd.read_csv('./log-data/May-17th-2022-03-47PM-Flight-Airdata.csv')

# %%
print(drone3mph.columns)
# Out:
# Index(['time(millisecond)', 'datetime(utc)', 'latitude', 'longitude',
#        'height_above_takeoff(feet)',
#        'height_above_ground_at_drone_location(feet)',
#        'ground_elevation_at_drone_location(feet)',
#        'altitude_above_seaLevel(feet)', 'height_sonar(feet)', 'speed(mph)',
#        'distance(feet)', 'mileage(feet)', 'satellites', 'gpslevel',
#        'voltage(v)', 'max_altitude(feet)', 'max_ascent(feet)',
#        'max_speed(mph)', 'max_distance(feet)', ' xSpeed(mph)', ' ySpeed(mph)',
#        ' zSpeed(mph)', ' compass_heading(degrees)', ' pitch(degrees)',
#        ' roll(degrees)', 'isPhoto', 'isVideo', 'rc_elevator', 'rc_aileron',
#        'rc_throttle', 'rc_rudder', 'rc_elevator(percent)',
#        'rc_aileron(percent)', 'rc_throttle(percent)', 'rc_rudder(percent)',
#        'gimbal_heading(degrees)', 'gimbal_pitch(degrees)', 'battery_percent',
#        'voltageCell1', 'voltageCell2', 'voltageCell3', 'voltageCell4',
#        'voltageCell5', 'voltageCell6', 'current(A)', 'battery_temperature(f)',
#        'altitude(feet)', 'ascent(feet)', 'flycStateRaw', 'flycState',
#        'message', 'X_m', 'Y_m'],
#       dtype='object')

# %%
def see_range(df, range, x = 'longitude', y = 'latitude'):
        fig, ax = plt.subplots()
        ax.plot(df[x], df[y], 'ko', ms=0.5)
        ax.plot(df[x].to_numpy()[range[0]:range[1]], df[y].to_numpy()[range[0]:range[1]], 'ro', ms=0.5)
        ax.set_aspect('equal')

# %%
see_range(drone3mph, [0,1150])

# %%
def lat_lon_to_meters(df, lon, lat, x0=-9147145.64754388, y0=3427601.097538607):
    R =  6378137.0
    Y = np.log(np.tan(np.pi / 4 + np.radians(lat) / 2)) * R
    X = np.radians(lon) * R
    df["X_m"] = X - x0
    df["Y_m"] = Y - y0

# %%
lat_lon_to_meters(drone1, drone1['longitude'], drone1['latitude'])
lat_lon_to_meters(drone2, drone2['longitude'], drone2['latitude'])

# %%
import copy
drone3mph = copy.deepcopy(drone1)
drone6mph = copy.deepcopy(drone1)
drone9mph = copy.deepcopy(drone1)
drone12mph = copy.deepcopy(drone2)

# %%
def crop_df(df, start, end, step=1):
    return df.drop(df.index[range(start, end, step)])

# %%
drone3mph = crop_df(drone3mph, 0, 500, step=1)
drone3mph = crop_df(drone3mph, -1, 3900 - len(drone3mph), -1)

# %%
drone6mph = crop_df(drone6mph, 0, 500+3900+720, step=1)
drone6mph = crop_df(drone6mph, -1, 2250 - len(drone6mph), -1)

# %%
drone9mph = crop_df(drone9mph, 0, 500+3900+720+2250+400, step=1)
drone9mph = crop_df(drone9mph, -1, 1510 - len(drone9mph), -1)

# %%
drone12mph = crop_df(drone12mph, 0, 830, step=1)
drone12mph = crop_df(drone12mph, -1, 1150 - len(drone12mph), -1)

# %% [markdown]
# To fix time, remove the intial time and divide by 1000 because time is in miliseconds

# %%
def fix_time(df):
    return (df["time"] - df["time"].to_numpy()[0])/1000

# for df in [drone3mph, drone6mph, drone9mph, drone12mph]:
drone3mph = drone3mph.rename(columns={"time(millisecond)": 'time'})
drone6mph = drone6mph.rename(columns={"time(millisecond)": 'time'})
drone9mph = drone9mph.rename(columns={"time(millisecond)": 'time'})
drone12mph = drone12mph.rename(columns={"time(millisecond)": 'time'})
drone3mph["time"] = fix_time(drone3mph)
drone6mph["time"] = fix_time(drone6mph)
drone9mph["time"] = fix_time(drone9mph)
drone12mph["time"] = fix_time(drone12mph)

# %%
plt.plot(range(len(drone12mph)),drone12mph["time"])

# %%
header = ["X_m", "Y_m", "time"]
drone3mph.to_csv('drone_traj_3.csv', columns = header)
drone6mph.to_csv('drone_traj_6.csv', columns = header)
drone9mph.to_csv('drone_traj_9.csv', columns = header)
drone12mph.to_csv('drone_traj_12.csv', columns = header)

# %% [markdown]
# in the terminal: `mv ./drone_traj_* ~/april_ws/src/bathydrone/gnc/traj_data`

# %% [markdown]
# ## Angle Test (pixhawk)

# %%
from scipy.io import loadmat  # this is the SciPy module that loads mat-files

mat = loadmat('./log-data/angle_test/2022-06-07_16-43-49.mat')  # load mat-file

#mat['yaw_mavlink_attitude_t'][:,1]
for key in list(mat.keys())[3:]:
    mat[key] = mat[key][:,1]
    print(key)
# Out:
# time_usec_mavlink_home_position_t
# spacing_mavlink_terrain_report_t
# system_status_mavlink_heartbeat_t
# clipping_1_mavlink_vibration_t
# vy_mavlink_airspeed_autocal_t
# chan4_raw_mavlink_rc_channels_t
# flags_mavlink_ekf_status_report_t
# servo2_raw_mavlink_servo_output_raw_t
# speed_z_mavlink_wind_t
# time_boot_ms_mavlink_position_target_global_int_t
# capabilities_mavlink_autopilot_version_t
# vx_mavlink_position_target_global_int_t
# type_mask_mavlink_position_target_global_int_t
# airspeed_variance_mavlink_ekf_status_report_t
# zmag_mavlink_scaled_imu3_t
# approach_y_mavlink_home_position_t
# error_rp_mavlink_ahrs_t
# temperature_mavlink_scaled_pressure_t
# xmag_mavlink_raw_imu_t
# middleware_sw_version_mavlink_autopilot_version_t
# param1_mavlink_mission_item_int_t
# target_network_mavlink_file_transfer_protocol_t
# wp_dist_mavlink_nav_controller_output_t
# seq_mavlink_mission_request_int_t
# approach_x_mavlink_home_position_t
# roll_mavlink_attitude_t
# hor_velocity_mavlink_adsb_vehicle_t
# frame_mavlink_mission_item_int_t
# param3_mavlink_command_long_t
# grid_spacing_mavlink_terrain_request_t
# latitude_mavlink_home_position_t
# yaw_rate_mavlink_position_target_global_int_t
# id_mavlink_raw_imu_t
# xacc_mavlink_scaled_imu3_t
# servo9_raw_mavlink_servo_output_raw_t
# Vcc_mavlink_hwstatus_t
# chan18_raw_mavlink_rc_channels_t
# time_usec_mavlink_aoa_ssa_t
# param4_mavlink_command_long_t
# lng_mavlink_ahrs2_t
# cog_mavlink_gps_raw_int_t
# param3_mavlink_mission_item_int_t
# product_id_mavlink_autopilot_version_t
# target_system_mavlink_param_request_list_t
# groundspeed_mavlink_vfr_hud_t
# h_acc_mavlink_gps_raw_int_t
# EAS2TAS_mavlink_airspeed_autocal_t
# temperature_mavlink_scaled_imu2_t
# raw_press_mavlink_sensor_offsets_t
# xgyro_mavlink_scaled_imu3_t
# target_component_mavlink_autopilot_version_request_t
# brkval_mavlink_meminfo_t
# clipping_2_mavlink_vibration_t
# rssi_mavlink_radio_status_t
# req_stream_id_mavlink_request_data_stream_t
# altitude_mavlink_ahrs2_t
# start_stop_mavlink_request_data_stream_t
# accel_cal_z_mavlink_sensor_offsets_t
# servo8_raw_mavlink_servo_output_raw_t
# errors_count3_mavlink_sys_status_t
# temperature_mavlink_scaled_imu3_t
# mag_declination_mavlink_sensor_offsets_t
# yaw_mavlink_gps2_raw_t
# lon_mavlink_global_position_int_t
# zgyro_mavlink_scaled_imu3_t
# lon_mavlink_gps_raw_int_t
# x_mavlink_home_position_t
# alt_mavlink_vfr_hud_t
# yaw_mavlink_gps_raw_int_t
# lat_mavlink_adsb_vehicle_t
# noise_mavlink_radio_status_t
# aspd_error_mavlink_nav_controller_output_t
# afy_mavlink_position_target_global_int_t
# pitchspeed_mavlink_attitude_t
# accel_cal_y_mavlink_sensor_offsets_t
# terrain_alt_variance_mavlink_ekf_status_report_t
# zgyro_mavlink_scaled_imu2_t
# lat_mavlink_gps2_raw_t
# afz_mavlink_position_target_global_int_t
# z_mavlink_home_position_t
# lat_mavlink_gps_raw_int_t
# target_system_mavlink_command_ack_t
# epv_mavlink_gps_raw_int_t
# vendor_id_mavlink_autopilot_version_t
# rssi_mavlink_radio_t
# tslc_mavlink_adsb_vehicle_t
# param_value_mavlink_param_value_t
# servo5_raw_mavlink_servo_output_raw_t
# alt_mavlink_position_target_global_int_t
# chan13_raw_mavlink_rc_channels_t
# ver_velocity_mavlink_adsb_vehicle_t
# xacc_mavlink_raw_imu_t
# heading_mavlink_vfr_hud_t
# progress_mavlink_command_ack_t
# rxerrors_mavlink_radio_status_t
# vz_mavlink_position_target_global_int_t
# lon_mavlink_gps2_raw_t
# raw_temp_mavlink_sensor_offsets_t
# txbuf_mavlink_radio_status_t
# dgps_numch_mavlink_gps2_raw_t
# servo14_raw_mavlink_servo_output_raw_t
# roll_mavlink_ahrs2_t
# eph_mavlink_gps2_raw_t
# time_usec_mavlink_servo_output_raw_t
# state_x_mavlink_airspeed_autocal_t
# altitude_type_mavlink_adsb_vehicle_t
# servo4_raw_mavlink_servo_output_raw_t
# errors_count1_mavlink_sys_status_t
# flags_mavlink_adsb_vehicle_t
# servo13_raw_mavlink_servo_output_raw_t
# board_version_mavlink_autopilot_version_t
# press_abs_mavlink_scaled_pressure_t
# mission_type_mavlink_mission_request_int_t
# target_system_mavlink_command_long_t
# servo10_raw_mavlink_servo_output_raw_t
# time_usec_mavlink_gps_raw_int_t
# param_type_mavlink_param_value_t
# chan5_raw_mavlink_rc_channels_t
# approach_z_mavlink_home_position_t
# climb_mavlink_vfr_hud_t
# vx_mavlink_local_position_ned_t
# zacc_mavlink_raw_imu_t
# nav_bearing_mavlink_nav_controller_output_t
# req_message_rate_mavlink_request_data_stream_t
# chan16_raw_mavlink_rc_channels_t
# chan10_raw_mavlink_rc_channels_t
# vz_mavlink_local_position_ned_t
# chan11_raw_mavlink_rc_channels_t
# os_sw_version_mavlink_autopilot_version_t
# ymag_mavlink_scaled_imu2_t
# noise_mavlink_radio_t
# Pax_mavlink_airspeed_autocal_t
# errors_count4_mavlink_sys_status_t
# mag_ofs_y_mavlink_sensor_offsets_t
# time_boot_ms_mavlink_scaled_imu2_t
# fixed_mavlink_radio_t
# loaded_mavlink_terrain_report_t
# satellites_visible_mavlink_gps_raw_int_t
# vel_mavlink_gps2_raw_t
# errors_comm_mavlink_sys_status_t
# freemem_mavlink_meminfo_t
# alt_ellipsoid_mavlink_gps2_raw_t
# lat_mavlink_terrain_report_t
# param_index_mavlink_param_value_t
# lat_mavlink_ahrs2_t
# temperature_press_diff_mavlink_scaled_pressure2_t
# servo1_raw_mavlink_servo_output_raw_t
# clipping_0_mavlink_vibration_t
# load_mavlink_sys_status_t
# zmag_mavlink_raw_imu_t
# gyro_cal_x_mavlink_sensor_offsets_t
# param7_mavlink_command_long_t
# battery_remaining_mavlink_sys_status_t
# vx_mavlink_global_position_int_t
# omegaIz_mavlink_ahrs_t
# state_z_mavlink_airspeed_autocal_t
# lon_mavlink_adsb_vehicle_t
# latitude_mavlink_gps_global_origin_t
# vibration_x_mavlink_vibration_t
# servo16_raw_mavlink_servo_output_raw_t
# xmag_mavlink_scaled_imu2_t
# error_yaw_mavlink_ahrs_t
# servo11_raw_mavlink_servo_output_raw_t
# longitude_mavlink_home_position_t
# alt_mavlink_gps2_raw_t
# v_acc_mavlink_gps_raw_int_t
# target_component_mavlink_file_transfer_protocol_t
# hdg_acc_mavlink_gps2_raw_t
# direction_mavlink_wind_t
# vy_mavlink_global_position_int_t
# pending_mavlink_terrain_report_t
# chan17_raw_mavlink_rc_channels_t
# h_acc_mavlink_gps2_raw_t
# time_usec_mavlink_gps2_raw_t
# xtrack_error_mavlink_nav_controller_output_t
# servo7_raw_mavlink_servo_output_raw_t
# mag_ofs_z_mavlink_sensor_offsets_t
# zmag_mavlink_scaled_imu2_t
# servo12_raw_mavlink_servo_output_raw_t
# target_system_mavlink_autopilot_version_request_t
# ymag_mavlink_scaled_imu3_t
# Vcc_mavlink_power_status_t
# fixed_mavlink_radio_status_t
# accel_cal_x_mavlink_sensor_offsets_t
# distance_mavlink_rangefinder_t
# txbuf_mavlink_radio_t
# diff_pressure_mavlink_airspeed_autocal_t
# time_unix_usec_mavlink_system_time_t
# result_param2_mavlink_command_ack_t
# omegaIy_mavlink_ahrs_t
# chan12_raw_mavlink_rc_channels_t
# yacc_mavlink_scaled_imu2_t
# flags_mavlink_power_status_t
# epv_mavlink_gps2_raw_t
# uid_mavlink_autopilot_version_t
# nav_roll_mavlink_nav_controller_output_t
# yaw_mavlink_ahrs2_t
# y_mavlink_mission_item_int_t
# satellites_visible_mavlink_gps2_raw_t
# dgps_age_mavlink_gps2_raw_t
# time_boot_ms_mavlink_system_time_t
# velocity_variance_mavlink_ekf_status_report_t
# hdg_mavlink_global_position_int_t
# severity_mavlink_statustext_t
# servo6_raw_mavlink_servo_output_raw_t
# command_mavlink_mission_item_int_t
# gyro_cal_z_mavlink_sensor_offsets_t
# press_diff_mavlink_scaled_pressure2_t
# zgyro_mavlink_raw_imu_t
# mission_type_mavlink_mission_item_int_t
# target_bearing_mavlink_nav_controller_output_t
# vz_mavlink_global_position_int_t
# lat_mavlink_global_position_int_t
# z_mavlink_local_position_ned_t
# heading_mavlink_adsb_vehicle_t
# lon_mavlink_terrain_report_t
# ygyro_mavlink_scaled_imu2_t
# xmag_mavlink_scaled_imu3_t
# Vservo_mavlink_power_status_t
# result_mavlink_command_ack_t
# alt_error_mavlink_nav_controller_output_t
# I2Cerr_mavlink_hwstatus_t
# omegaIx_mavlink_ahrs_t
# ratio_mavlink_airspeed_autocal_t
# ygyro_mavlink_raw_imu_t
# remrssi_mavlink_radio_t
# tc1_mavlink_timesync_t
# time_boot_ms_mavlink_scaled_imu3_t
# eph_mavlink_gps_raw_int_t
# lon_int_mavlink_position_target_global_int_t
# x_mavlink_mission_item_int_t
# ICAO_address_mavlink_adsb_vehicle_t
# time_boot_ms_mavlink_rc_channels_t
# time_boot_ms_mavlink_global_position_int_t
# freemem32_mavlink_meminfo_t
# onboard_control_sensors_health_mavlink_sys_status_t
# param2_mavlink_mission_item_int_t
# Pby_mavlink_airspeed_autocal_t
# current_battery_mavlink_sys_status_t
# current_height_mavlink_terrain_report_t
# command_mavlink_command_ack_t
# type_mavlink_heartbeat_t
# confirmation_mavlink_command_long_t
# chan7_raw_mavlink_rc_channels_t
# base_mode_mavlink_heartbeat_t
# chan14_raw_mavlink_rc_channels_t
# yaw_mavlink_attitude_t
# yacc_mavlink_scaled_imu3_t
# param1_mavlink_command_long_t
# seq_mavlink_mission_item_int_t
# altitude_mavlink_adsb_vehicle_t
# chan1_raw_mavlink_rc_channels_t
# remnoise_mavlink_radio_status_t
# vx_mavlink_airspeed_autocal_t
# target_system_mavlink_mission_request_int_t
# target_component_mavlink_command_long_t
# param5_mavlink_command_long_t
# squawk_mavlink_adsb_vehicle_t
# vel_acc_mavlink_gps_raw_int_t
# target_component_mavlink_param_request_list_t
# cog_mavlink_gps2_raw_t
# z_mavlink_mission_item_int_t
# y_mavlink_local_position_ned_t
# port_mavlink_servo_output_raw_t
# chunk_seq_mavlink_statustext_t
# id_mavlink_statustext_t
# current_mavlink_mission_item_int_t
# chan8_raw_mavlink_rc_channels_t
# time_boot_ms_mavlink_scaled_pressure_t
# vz_mavlink_airspeed_autocal_t
# lat_mavlink_terrain_request_t
# ymag_mavlink_raw_imu_t
# Pcz_mavlink_airspeed_autocal_t
# afx_mavlink_position_target_global_int_t
# pitch_mavlink_ahrs2_t
# accel_weight_mavlink_ahrs_t
# terrain_height_mavlink_terrain_report_t
# press_diff_mavlink_scaled_pressure_t
# errors_count2_mavlink_sys_status_t
# target_system_mavlink_file_transfer_protocol_t
# rxerrors_mavlink_radio_t
# target_component_mavlink_command_ack_t
# target_component_mavlink_request_data_stream_t
# lon_mavlink_terrain_request_t
# voltage_mavlink_rangefinder_t
# drop_rate_comm_mavlink_sys_status_t
# emitter_type_mavlink_adsb_vehicle_t
# onboard_control_sensors_enabled_mavlink_sys_status_t
# ts1_mavlink_timesync_t
# time_boot_ms_mavlink_scaled_pressure2_t
# param6_mavlink_command_long_t
# hdg_acc_mavlink_gps_raw_int_t
# remnoise_mavlink_radio_t
# servo15_raw_mavlink_servo_output_raw_t
# pos_horiz_variance_mavlink_ekf_status_report_t
# vy_mavlink_position_target_global_int_t
# pos_vert_variance_mavlink_ekf_status_report_t
# vy_mavlink_local_position_ned_t
# nav_pitch_mavlink_nav_controller_output_t
# rssi_mavlink_rc_channels_t
# yawspeed_mavlink_attitude_t
# speed_mavlink_wind_t
# vibration_y_mavlink_vibration_t
# chan15_raw_mavlink_rc_channels_t
# seq_mavlink_mission_current_t
# time_usec_mavlink_vibration_t
# SSA_mavlink_aoa_ssa_t
# throttle_mavlink_vfr_hud_t
# press_abs_mavlink_scaled_pressure2_t
# mask_mavlink_terrain_request_t
# target_component_mavlink_mission_request_int_t
# vibration_z_mavlink_vibration_t
# fix_type_mavlink_gps2_raw_t
# target_system_mavlink_mission_item_int_t
# chancount_mavlink_rc_channels_t
# compass_variance_mavlink_ekf_status_report_t
# airspeed_mavlink_vfr_hud_t
# yacc_mavlink_raw_imu_t
# xgyro_mavlink_scaled_imu2_t
# gyro_cal_y_mavlink_sensor_offsets_t
# temperature_mavlink_raw_imu_t
# alt_ellipsoid_mavlink_gps_raw_int_t
# param2_mavlink_command_long_t
# zacc_mavlink_scaled_imu2_t
# onboard_control_sensors_present_mavlink_sys_status_t
# xgyro_mavlink_raw_imu_t
# fix_type_mavlink_gps_raw_int_t
# renorm_val_mavlink_ahrs_t
# yaw_mavlink_position_target_global_int_t
# v_acc_mavlink_gps2_raw_t
# ygyro_mavlink_scaled_imu3_t
# target_system_mavlink_request_data_stream_t
# temperature_mavlink_scaled_pressure2_t
# time_usec_mavlink_raw_imu_t
# custom_mode_mavlink_heartbeat_t
# time_boot_ms_mavlink_local_position_ned_t
# lat_int_mavlink_position_target_global_int_t
# remrssi_mavlink_radio_status_t
# time_boot_ms_mavlink_attitude_t
# y_mavlink_home_position_t
# alt_mavlink_global_position_int_t
# param_count_mavlink_param_value_t
# pitch_mavlink_attitude_t
# chan6_raw_mavlink_rc_channels_t
# x_mavlink_local_position_ned_t
# vel_acc_mavlink_gps2_raw_t
# relative_alt_mavlink_global_position_int_t
# rollspeed_mavlink_attitude_t
# autocontinue_mavlink_mission_item_int_t
# altitude_mavlink_home_position_t
# mavlink_version_mavlink_heartbeat_t
# target_component_mavlink_mission_item_int_t
# time_usec_mavlink_gps_global_origin_t
# altitude_mavlink_gps_global_origin_t
# AOA_mavlink_aoa_ssa_t
# coordinate_frame_mavlink_position_target_global_int_t
# xacc_mavlink_scaled_imu2_t
# flight_sw_version_mavlink_autopilot_version_t
# servo3_raw_mavlink_servo_output_raw_t
# voltage_battery_mavlink_sys_status_t
# chan2_raw_mavlink_rc_channels_t
# command_mavlink_command_long_t
# chan3_raw_mavlink_rc_channels_t
# longitude_mavlink_gps_global_origin_t
# temperature_press_diff_mavlink_scaled_pressure_t
# autopilot_mavlink_heartbeat_t
# alt_mavlink_gps_raw_int_t
# mag_ofs_x_mavlink_sensor_offsets_t
# param4_mavlink_mission_item_int_t
# vel_mavlink_gps_raw_int_t
# chan9_raw_mavlink_rc_channels_t
# zacc_mavlink_scaled_imu3_t
# state_y_mavlink_airspeed_autocal_t
